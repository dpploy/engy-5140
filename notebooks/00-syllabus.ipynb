# %% [markdown]
# Engy-5140 Fall 2019 UMass Lowell; Prof. V. F. de Almeida **05Sep2019**
#
# # ENGY-5140 Chemical and Nuclear Waste Processing – Course Syllabus

# %% [markdown]
# ### Instructors: Prof. Valmor F. de Almeida and Prof. Sukesh Aghara
# **Office:**    Pinanski Hall 301G. <br>
# **Email:**     valmor_dealmeida@uml.edu. <br>
# **Web:**       https://www.uml.edu/Engineering/Chemical/faculty/de-Almeida-Valmor.aspx <br>
# **Lectures:** Ball Hall 412, Tue, Thu 5:00 – 6:15 pm. <br>
# **Days meetings total Tue/Thu:** 27. <br>
# **Week meetings total:** 15. <br>
# <span style="color:red">**Website:**</span> On-line course [repository](https://github.com/dpploy/engy-5140) and UMass Lowell Blackboard System. <br>
# **Office hours and location:** meet at after lectures, Tue and Thu. <br>
# **Other means of contact:**  email. <br>
# <span style="color:red">**Computational support:**</span> UML Linux Group Fall 2019 meetings, Fridays 4:00 – 5:00 pm, UMass Lowell, Innovation Hub, 110 Cannal, 3rd floor, room 318, Lowell. <br>
# **Teaching assistant:** please see office hours. <br>
# **Catalog description:** <br>
# History of nuclear waste disposal; engineering design of disposal systems. Present status of waste and the character and quantities of future wastes. Review of disposal concepts on a generic basis. The national plan for waste disposal.<br>
# **Prerequisites:** none.<br>
# **Co-requisites:** none.<br>
# **Course designation:** elective. <br>
# <span style="color:red">**Suggested:**</span> [ChEn-3170](https://github.com/dpploy/chen-3170) Computational Methods in Chemical Engineering, ChEn-3110 Themodynamics, ChEn-3100 Chemical Separations, and ChEn-4030 Chemical Reaction Engineering.  <br>

# %% [markdown]
# #### References
#  1. [*Hazardous Waste Management*](https://www.amazon.com/Hazardous-Waste-Management-Michael-LaGrega-ebook/dp/B00H8VM0I4/ref=sr_1_1?keywords=lagrega&qid=1567710963&s=digital-text&sr=1-1), M. D. LaGrega, P. L. Buckingham, and J. C. Evans, Waveland Press, Inc., 2010, 2$^\text{nd}$ edition, 1202 pp.
#  2. [*Chemical Thermodynamics of Solid Solutions of Interest in Nuclear Waste Management: A State-of-the-Art Report*](https://www.oecd-nea.org/science/pubs/2007/6255-DB-chemical-thermodyn-10.pdf), J. Bruno, D. Bosbash, D. Kulik, A. Navrotsky, OECD, 2007, 266 pp.
#  3. [*The Nuclear Fuel Cycle*](http://www.ans.org/store/item-350024/), N. Tsoulfanidis, ANS, 2013, 462 pp.
#  4. [*Glasses, Glass-Ceramics and Ceramics for Immobilization of Highly Radioactive Nuclear Waste*](https://www.academia.edu/24561601/GLASSES_GLASS-CERAMICS_AND_CERAMICS_FOR_IMMOBILIZATION_OF_HIGHLY_RADIOACTIVE_NUCLEAR_WASTES),  D. Caurant, P. Loiseau, O. Majerus, V. Aubin-Chevaldonnet, I. Bardez, A. Quintas, Nova Science Publishers, Inc., 2009, 359 pp.
#  5. *Nuclear Chemical Engineering*, M. Benedict, T. H. Pigford, and H. W. Levi, McGraw-Hill Book Company, 1981, 2$^\text{nd}$ edition, 1008 pp.
#
# <span style="color:red">**Software needed for course and homework:**</span> Jupyter notebook; access options for this course<br>
#  1. Browser based cloud service: [Azure](https://notebooks.azure.com/). Login with your student UMass Lowell credentials and start a Jupyter Notebook. This is a free Microsoft cloud service.
#    + Your Azure copy of the repository will need to be updated throughout the semester. Here are two ways to do it:
#       - One way: on your *My Projects* area, select and delete the repository (engy-5140). Then *Upload GitHub Repo* again with a fresh copy of the course repository. Now you are done.
#       - Another way: on your existing Azure project (engy-5140) area, *Open a terminal* (click on the icon across the menu bar). Once the terminal is booted, issue the following Linux shell commands:
#           * cd library/notebooks
#           * git checkout *.ipynb
#           * git pull
#       - If all fail, please email me.
#  2. Use Binder at the course [repository](https://github.com/dpploy/engy-5140) (see instructions at the site).
#  3. [Anaconda](https://docs.anaconda.com/anaconda/install/#) free download (use the Python 3 version) and use (Mac OS X or Windows). After install, use [Anaconda-Navigator](https://docs.anaconda.com/anaconda/navigator/) to start a Jupyter Notebook.
#
# **Suplement materials:** On-line course [repository](https://github.com/dpploy/engy-5140) and UMass Lowell Blackboard System.

# %% [markdown]
# **Course topics:**
#  - Physicochemical processes
#  - Transport phenomena
#  - Chemical kinetics and thermodynamics
#  - System-level modeling and simulation
#
# **Grading notes:** for grading purposes the requirements for this course include:
#  + Homework every other week (individual)
#  + 2 Midterm exams (open notes/book in class)
#  + 1 Project as final exam (teams of a of 2 (ideal) or 3 (max) students; take home)
#
# Make up of late homework and project will be resolved on a case-by-case basis if there is enough evidence of a special circumstance. Homework, project, and exams announcements will be made via Blackboard and email distributed to the students.
#
# |**Course Grading Procedure** |**Value**|
# |:----------------------------|:-------:|
# | Homework                    |  25%    |
# | Midterm exams               |  50%    |
# | Project                     |  25%    |
#
# |**Letter Grade Scale** |**Value**|
# |:----------------------|:-------:|
# | A                     | 92+     |
# | A-                    | 87–91.9 |
# | B+                    | 82–86.9 |
# | B                     | 77–81.9 |
# | B-                    | 72–76.9 |
# | C+                    | 67–71.9 |
# | C                     | 62–66.9 |
# | C-                    | 58–61.9 |
# | D+                    | 54–57.9 |
# | D                     | 50–53.9 |
# | F                     | <50     |

# %% [markdown]
# **Course outcomes:**
#  1. Explain fundamentals of waste processing.
#  2. Explain waste management practices.
#  3. Understand the basic physicochemical processes in waste processing.
#  4. Explain stabilization and solidification.
#  5. Describe basic thermal methods.
#  6. Understand site remediation and risk analysis.
#  7. Explain nuclear waste forms.
#  8. Understand nuclear fuel reprocessing and radioactive waste management.
#
# **Relation of course outcomes to ABET Criterion 3:**
#
# |**Course Outcomes** |**ABET Criterion 3**|
# |:----------------------|:-------:|
# | 1                     | c, j     |
# | 2                     | a, e |
# | 3                     | a, e |
# | 4                     | a, e |
# | 5                     | a, e |
# | 6                     | a, e |
# | 7                     | a, e |
# | 8                     | c, d, e, f, g, h, i, j, k |

# %% [markdown]
# **Schedule:**
#
# |  Week  |Day| Date      | Notebook   | Assessment   | Note   |
# | :----  |:-:|:---------:|:-----------|:-------------|:------:|
# | **1**  |Th |**05Sep19**|    01      |     -        |   Fundamentals  |
# | 2      |Tu |  10Sep19  |    "      |      -       |   "  |
# | 2      |Th |  12Sep19  |    01, 02       |    distribute HWK 01        |   Fundamentals, Physicochemical Processes    |
# | 3      |Tu |  17Sep19  |    02       |      -       |   Physicochemical Processes    |
# | 3      |Th |  19Sep19  |    02       |      -       |   Physicochemical processes    |
# | 4      |Tu |  24Sep19  |    "       |      -       |  Classwork (ANS Global)|
# | 4      |Th |  26Sep19  |    03       |   collect HWK 01; distribute HWK 02       |   Stabilization and Solidification (ANS Global)    |
# |.|.|.|.|.|.|
# | **5**  |Tu |**01Oct19**|     02      |     -        |   Physicochemical Processes    |
# | 5      |Th |  03Oct19  |     01-04   |     midterm      |   in-class    |
# | 6      |Tu |  08Oct19  |     05      |      -       |   Thermal methods    |
# | 6      |Th |  10Oct19  |     "      |      HWK 03       |   "   |
# | ~~7~~      |~~M~~ | ~~14Oct19~~ |   -   |      -       | Columbus Holiday |
# | ~~7~~      |~~Tu~~| ~~15Oct18~~ |    -  |       -      | Monday Schedule  |
# | 7      |Th |  17Oct19  |     06      |       -      |    Land Disposal    |
# | 8      |Tu |  22Oct19  |      "     |       -      |     "   |
# | 8      |Th |  24Oct19  |      07     |      HWK 04      |    Sub-soil Transport    |
# | 9      |Tu |  29Oct19  |     "      |       -      |    "    |
# | 9      |Th |  31Oct19  |     08      |       -      |   Nuclear fuel reprocessing     |
# |.|.|.|.|.|.|
# | **10** |Tu |**05Nov19**|     08      |         -           |   Nuclear fuel reprocessing   |
# | 10     |Th |  07Nov19  |     05-08      |        midterm           |        in-class              |
# | 11     |Tu |  12Nov19  |     09      |         -           | Site Remediation Risk Analysis (Prof. Aghara)        (AIChE)             |
# | 11     |Th |  14Nov19  |      "     |         HWK 05       |  Site Remediation Risk Analysis (Prof. Aghara)  (AIChE)    |
# | 12     |Tu |  19Nov19  |     10      |         -           |         Radioactive waste management             |
# | 12     |Th |  21Nov19  |     "      |         -           |         "             |
# | 13     |Tu |  26Nov19  |     11      |          -          |         Nuclear waste forms             |
# | ~~13~~     |~~W~~ |  ~~27Nov19~~ |   -  |          -          | Thanksgiving Recess   |
# | ~~13~~     |~~Th~~|  ~~28Nov19~~ |   -  |         -           | Thanksgiving Recess   |
# | ~~13~~     |~~F~~ |  ~~29Nov19~~ |   -  |         -           | Thanksgiving Recess   |
# |.|.|.|.|.|.|
# | **14** |Tu |**03Dec19**|    11       |        -            |       Nuclear waste forms               |
# | 14     |Th |  05Dec19  |     12      |        HWK 06            |    Chemical thermodynamics of actinides               |
# | 15     |Tu |  10Dec19  |     "      |        -            |        "              |
# | 15     |Th |  12Dec19  |     Review      |         -           |  Last day of classes  |
# |.|.|.|.|.|.|
# | **Final** |-|  xxDec19 |      -     |Final project    |xx:xx-xx:xx                   |

# %% [markdown]
# <span style="color:red">**Classroom Conduct:**</span> <span style="color:red">Students are expected to exhibit professional and respectful behavior that is conducive to a mutually beneficial learning environment in the classroom. Examples of inappropriate behavior include: text messaging, listening to music, cell phone use (other than the campus alert system), late arrivals, early departures, use of laptops for other than class purposes, disrespectful comments or behavior, intentional disruptions, failure to follow faculty directives, etc. Students in violation of these standards may be asked to leave class and/or be referred to the Dean of Students for disciplinary action.</span>
#
# <span style="color:red">**Academic Integrity:**</span> <span style="color:red">Cheating and plagiarism will not be tolerated. A first offense will result in a failing grade for the assignment/exam in question and a formal filing with the Office of Provost according to the Academic Integrity Policy. A second offense could lead to a failing grade in the course, suspension or expulsion, as detailed in the policy, defined [here](https://www.uml.edu/Catalog/Undergraduate/Policies/Academic-Policies/Academic-Integrity.aspx).</span>
#
# **Instructional Resources:**  The Centers for Learning and Academic Support Services provide many tutoring resources; more details are available [here](https://www.uml.edu/class/)
# Technology Resources: For a listing of available computing and software resources available to students, [visit here]( https://www.uml.edu/IT/Services/DLC/).
#
# **Accommodations:** In accordance with University policy and the ADA, accommodations are provided for students with documented disabilities. If you have a disability, please contact the Office of Disability Services as soon as possible. Their office is in UC 220 (978-934-4574, Disability@uml.edu). Documentation of disability is confidential. Requests for accommodation for religious reasons should be directed to Equal Opportunity and Outreach at 978-934-3565, Wannalancit Mills, Suite 301.
#
# **Counseling Services:** As part of the Wellness Center, Counseling Services at UMass Lowell provide mental health counseling, consultation and referrals to help students achieve personal and academic success. They also assist students in better understanding and coping with their feelings, relationships, and choices surrounding their academic success. [Visit](https://www.uml.edu/student-services/Counseling/)
# Veterans’ Services: UMass Lowell is committed to helping our military students take full advantage of all the educational benefits available through the federal and state governments. For complete information on the services and resources available please visit our [website](https://www.uml.edu/student-services/Veterans/).
# University Cancellation Information: If campus is closed (most likely for weather), visit the website for announcements relevant to the class.
